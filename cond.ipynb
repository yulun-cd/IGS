# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import glob

# %%
# Read in data

BP = pd.read_csv('data/con_var/BP.csv')
Tmp = pd.read_csv('data/con_var/TEM.csv')
Prec = pd.read_csv('data/con_var/PRE.csv')

# %%
files = glob.glob('data/con_var/wsp*.csv')
wsp = pd.concat(pd.read_csv(f) for f in files)
wsp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113880 entries, 0 to 61319
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Site                     113880 non-null  object
#  1   Species                  113880 non-null  object
#  2   ReadingDateTime          113880 non-null  object
#  3   Value                    104283 non-null  float64
#  4   Units                    113880 non-null  object
#  5   Provisional or Ratified  113880 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 6.1+ MB

# %%
wsp.reset_index(inplace=True, drop=True)

# %%
wsp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113880 entries, 0 to 113879
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Site                     113880 non-null  object
#  1   Species                  113880 non-null  object
#  2   ReadingDateTime          113880 non-null  object
#  3   Value                    104283 non-null  float64
#  4   Units                    113880 non-null  object
#  5   Provisional or Ratified  113880 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 5.2+ MB

# %%
BP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52560 entries, 0 to 52559
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Site                     52560 non-null  object
#  1   Species                  52560 non-null  object
#  2   ReadingDateTime          52560 non-null  object
#  3   Value                    34287 non-null  float64
#  4   Units                    52560 non-null  object
#  5   Provisional or Ratified  52560 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 2.4+ MB

# %%
Tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52560 entries, 0 to 52559
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Site                     52560 non-null  object
#  1   Species                  52560 non-null  object
#  2   ReadingDateTime          52560 non-null  object
#  3   Value                    49340 non-null  float64
#  4   Units                    52560 non-null  object
#  5   Provisional or Ratified  52560 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 2.4+ MB

# %%
Prec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26280 entries, 0 to 26279
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Site                     26280 non-null  object
#  1   Species                  26280 non-null  object
#  2   ReadingDateTime          26280 non-null  object
#  3   Value                    25937 non-null  float64
#  4   Units                    26280 non-null  object
#  5   Provisional or Ratified  26280 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 1.2+ MB

# %%
def trans(df):
    new_df = pd.DataFrame(df.loc[:8759, 'ReadingDateTime'])
    for site in df['Site'].unique():
        new_df[site] = df[df['Site']==site].Value.values
    return new_df

# %%
BP = trans(BP)
BP.describe()
# Out:
#                BG1          CD1  GR4  GB6          HK6          RG3
# count  8545.000000  8640.000000  0.0  0.0  8525.000000  8577.000000
# mean   1009.576829  1007.237153  NaN  NaN  1003.239883  1011.351638
# std      12.519591    11.737971  NaN  NaN    12.753954    11.997753
# min     965.000000   965.000000  NaN  NaN   958.000000   969.000000
# 25%    1002.000000  1000.000000  NaN  NaN   995.000000  1004.000000
# 50%    1010.000000  1008.000000  NaN  NaN  1003.000000  1012.000000
# 75%    1018.000000  1015.000000  NaN  NaN  1013.000000  1019.000000
# max    1038.000000  1036.000000  NaN  NaN  1037.000000  1040.000000

# %%
BP.drop(['GR4', 'GB6'], axis=1, inplace=True)
BP.plot(x='ReadingDateTime')
# Out:
# <AxesSubplot:xlabel='ReadingDateTime'>

# %%
Tmp = trans(Tmp)
Tmp.describe()
# Out:
#                BG1          BQ7          RG1          RG3          HK6  \
# count  8372.000000  8525.000000  7455.000000  8394.000000  8123.000000
# mean     13.301839    12.285982    11.912274    11.033238    12.884033
# std       6.088114     6.266272     5.946373     6.002896    11.312809
# min      -3.000000    -6.000000   -14.000000    -7.000000  -239.000000
# 25%       9.000000     8.000000     8.000000     7.000000     9.000000
# 50%      13.000000    12.000000    11.000000    10.000000    12.000000
# 75%      18.000000    17.000000    16.000000    15.000000    17.000000
# max      38.000000    36.000000    35.000000    34.000000    39.000000
#
#                RI2
# count  8471.000000
# mean     12.584347
# std       6.447605
# min      -4.000000
# 25%       8.000000
# 50%      12.000000
# 75%      17.000000
# max      38.000000

# %% [markdown]
# The minimum value of **HK6** is very abnormal

# %%
Tmp.plot(x='ReadingDateTime', linewidth=0.2)
# Out:
# <AxesSubplot:xlabel='ReadingDateTime'>

# %%
Tmp.sort_values(by='HK6', ascending=True).head(50)
# Out:
#        ReadingDateTime   BG1   BQ7   RG1   RG3    HK6   RI2
# 1262  22/02/2019 14:00  16.0  14.0  16.0  14.0 -239.0  17.0
# 1263  22/02/2019 15:00  16.0  14.0  15.0  15.0 -214.0  18.0
# 3423  23/05/2019 15:00   NaN  26.0  22.0  21.0 -200.0  26.0
# 1264  22/02/2019 16:00  14.0  12.0  13.0  13.0 -185.0  16.0
# 3424  23/05/2019 16:00   NaN  25.0  22.0  21.0 -184.0  26.0
# 3738  05/06/2019 18:00  17.0  16.0  14.0  14.0 -180.0   NaN
# 3425  23/05/2019 17:00   NaN  23.0  20.0  19.0 -174.0  24.0
# 3737  05/06/2019 17:00  18.0  17.0  15.0  15.0 -173.0   NaN
# 3590  30/05/2019 14:00  24.0  24.0  21.0  21.0 -167.0  24.0
# 3426  23/05/2019 18:00   NaN  21.0  18.0  18.0 -161.0  23.0
# 3422  23/05/2019 14:00   NaN  25.0  23.0  21.0 -160.0  26.0
# 3739  05/06/2019 19:00  16.0  16.0  14.0  14.0 -147.0   NaN
# 3589  30/05/2019 13:00  24.0  24.0  20.0  20.0 -144.0  23.0
# 1265  22/02/2019 17:00  11.0   9.0  11.0  11.0 -140.0  14.0
# 3591  30/05/2019 15:00  24.0  24.0  21.0  20.0 -138.0  24.0
# 3427  23/05/2019 19:00   NaN  19.0  16.0  15.0 -132.0  20.0
# 1261  22/02/2019 13:00  16.0  14.0  16.0  12.0 -118.0  15.0
# 3740  05/06/2019 20:00  16.0  15.0  13.0  13.0 -117.0   NaN
# 3428  23/05/2019 20:00   NaN  17.0  14.0  13.0 -108.0  17.0
# 1266  22/02/2019 18:00  10.0   8.0   9.0   9.0  -95.0  12.0
# 3592  30/05/2019 16:00  24.0  23.0  20.0  20.0  -94.0  23.0
# 3741  05/06/2019 21:00  15.0  14.0  12.0  12.0  -89.0   NaN
# 3429  23/05/2019 21:00   NaN  15.0  13.0  12.0  -84.0  15.0
# 3594  30/05/2019 18:00  23.0  21.0  18.0  18.0  -77.0  21.0
# 3400  22/05/2019 16:00   NaN  22.0  20.0  19.0  -72.0  24.0
# 3593  30/05/2019 17:00  23.0  22.0  19.0  19.0  -69.0  22.0
# 3401  22/05/2019 17:00   NaN  20.0  19.0  19.0  -61.0  22.0
# 3742  05/06/2019 22:00  15.0  14.0  11.0  10.0  -60.0   NaN
# 3402  22/05/2019 18:00   NaN  19.0  18.0  18.0  -58.0  21.0
# 3430  23/05/2019 22:00   NaN  14.0  12.0  11.0  -54.0  14.0
# 3595  30/05/2019 19:00  22.0  20.0  18.0  17.0  -48.0  20.0
# 2104  29/03/2019 16:00  17.0  15.0  17.0  17.0  -47.0  20.0
# 3596  30/05/2019 20:00  21.0  19.0  16.0  15.0  -43.0  18.0
# 1267  22/02/2019 19:00   8.0   7.0   7.0   7.0  -42.0  11.0
# 3431  23/05/2019 23:00   NaN  12.0  11.0  10.0  -40.0  12.0
# 2872  30/04/2019 16:00  17.0  15.0  18.0  16.0  -39.0  21.0
# 3399  22/05/2019 15:00   NaN  23.0  20.0  19.0  -38.0  24.0
# 2103  29/03/2019 15:00  18.0  16.0  18.0  18.0  -33.0  20.0
# 3403  22/05/2019 19:00   NaN  18.0  16.0  16.0  -23.0  18.0
# 1285  23/02/2019 13:00  17.0  15.0  16.0  15.0  -22.0  16.0
# 1447  02/03/2019 07:00  10.0   9.0   8.0   9.0  -11.0  10.0
# 3432  24/05/2019 00:00   NaN  12.0  11.0   9.0   -9.0  12.0
# 1287  23/02/2019 15:00  17.0  15.0  15.0  15.0   -7.0  18.0
# 1286  23/02/2019 14:00  17.0  15.0  16.0  16.0   -5.0  18.0
# 797   03/02/2019 05:00  -0.0  -1.0   NaN  -2.0    0.0  -2.0
# 745   01/02/2019 01:00   2.0   1.0   NaN  -0.0    0.0   1.0
# 799   03/02/2019 07:00  -1.0  -3.0   NaN  -3.0    0.0  -3.0
# 798   03/02/2019 06:00  -1.0  -1.0   NaN  -2.0    0.0  -2.0
# 744   01/02/2019 00:00   2.0   1.0   NaN  -0.0    0.0   1.0
# 725   31/01/2019 05:00  -3.0  -5.0   NaN  -7.0    0.0  -3.0

# %% [markdown]
# The values of HK6 seems to be very different from other sites, so the data might be problematic and hence removing it would be the best for the result.

# %%
Tmp.drop('HK6', axis=1, inplace=True)

# %%
Tmp.drop('RG1', axis=1, inplace=True)

# %%
Tmp.plot(x='ReadingDateTime', linewidth=0.2)
# Out:
# <AxesSubplot:xlabel='ReadingDateTime'>

# %%
Prec = trans(Prec)
Prec.describe()
# Out:
#                BG1          BQ7     RG1
# count  8547.000000  8697.000000  8693.0
# mean      0.004329     0.214557     0.0
# std       0.067415     1.235385     0.0
# min       0.000000     0.000000     0.0
# 25%       0.000000     0.000000     0.0
# 50%       0.000000     0.000000     0.0
# 75%       0.000000     0.000000     0.0
# max       2.000000    29.000000     0.0

# %%
wsp = trans(wsp)

# %%
wsp.describe()
# Out:
#        BT5          BX2          BQ7          BX1          BT8          GR7  \
# count  0.0  8758.000000  8710.000000  8731.000000  8578.000000  8701.000000
# mean   NaN     1.320324     1.278037     1.669832     2.612031     0.473095
# std    NaN     0.961925     0.775348     0.793898     1.758251     0.325465
# min    NaN     0.300000     0.400000     0.600000     0.400000     0.000000
# 25%    NaN     0.600000     0.700000     1.000000     1.200000     0.200000
# 50%    NaN     1.100000     1.000000     1.500000     2.300000     0.400000
# 75%    NaN     1.900000     1.600000     2.100000     3.600000     0.600000
# max    NaN     8.000000     5.100000     5.800000    13.500000     2.600000
#
#                GR4          GB6          GN6          RG1          RG3  \
# count  8570.000000  8760.000000  8697.000000  8749.000000  8567.000000
# mean      1.324702     2.320890     0.720720     1.062693     2.551768
# std       0.814898     1.635135     0.907723     0.708365     2.175922
# min       0.200000     0.100000     0.000000     0.000000     0.100000
# 25%       0.600000     1.100000     0.100000     0.500000     0.900000
# 50%       1.100000     1.900000     0.300000     0.900000     1.900000
# 75%       1.800000     3.100000     1.100000     1.500000     3.700000
# max       5.000000    11.000000     6.000000     5.000000    13.900000
#
#                GR8          TH4
# count  8702.000000  8760.000000
# mean      0.993634     1.601598
# std       0.672406     0.752781
# min       0.000000     0.400000
# 25%       0.500000     1.000000
# 50%       0.800000     1.500000
# 75%       1.400000     2.000000
# max       4.600000     6.400000

# %%
wsp.drop('BT5', axis=1, inplace=True)

# %%
def fill_nan(df):
    for col in df.columns[1:]:
        val = df[col].values.copy()
        for i in range(len(val)):
            if np.isnan(val[i]):
                j = 1
                while (np.isnan(val[i+j])) & (j < 12):
                    j += 1
                if j==12:
                    for z in range(j+1):
                        val[i+z] = val[i+z-24]
                val[i] = val[i-1] + (val[i+j] - val[i-1]) / (j+1)
        df[col] = val

# %%
fill_nan(BP)
BP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ReadingDateTime  8760 non-null   object
#  1   BG1              8760 non-null   float64
#  2   CD1              8760 non-null   float64
#  3   HK6              8760 non-null   float64
#  4   RG3              8760 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 342.3+ KB

# %%
fill_nan(Tmp)
Tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ReadingDateTime  8760 non-null   object
#  1   BG1              8760 non-null   float64
#  2   BQ7              8760 non-null   float64
#  3   RG3              8760 non-null   float64
#  4   RI2              8760 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 342.3+ KB

# %%
fill_nan(Prec)
Prec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ReadingDateTime  8760 non-null   object
#  1   BG1              8760 non-null   float64
#  2   BQ7              8760 non-null   float64
#  3   RG1              8760 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 273.9+ KB

# %%
fill_nan(wsp)
wsp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ReadingDateTime  8760 non-null   object
#  1   BX2              8760 non-null   float64
#  2   BQ7              8760 non-null   float64
#  3   BX1              8760 non-null   float64
#  4   BT8              8760 non-null   float64
#  5   GR7              8760 non-null   float64
#  6   GR4              8760 non-null   float64
#  7   GB6              8760 non-null   float64
#  8   GN6              8760 non-null   float64
#  9   RG1              8760 non-null   float64
#  10  RG3              8760 non-null   float64
#  11  GR8              8760 non-null   float64
#  12  TH4              8760 non-null   float64
# dtypes: float64(12), object(1)
# memory usage: 889.8+ KB

# %%
Prec.describe()
# Out:
#                BG1          BQ7     RG1
# count  8760.000000  8760.000000  8760.0
# mean      0.004224     0.215068     0.0
# std       0.066594     1.233028     0.0
# min       0.000000     0.000000     0.0
# 25%       0.000000     0.000000     0.0
# 50%       0.000000     0.000000     0.0
# 75%       0.000000     0.000000     0.0
# max       2.000000    29.000000     0.0

# %%
cond = pd.DataFrame(BP['ReadingDateTime'])
cond['bp_mean'] = BP[BP.columns[1:]].mean(axis=1)
cond['tmp_mean'] = Tmp[Tmp.columns[1:]].mean(axis=1)
cond['prec_mean'] = Prec['BQ7']
cond['wsp_mean'] = wsp[wsp.columns[1:]].mean(axis=1)

# %%
cond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ReadingDateTime  8760 non-null   object
#  1   bp_mean          8760 non-null   float64
#  2   tmp_mean         8760 non-null   float64
#  3   prec_mean        8760 non-null   float64
#  4   wsp_mean         8760 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 342.3+ KB

# %%
cond.to_csv('data/cond_hourly.csv', index=False)
