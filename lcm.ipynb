# %%
import rasterio as rio
from rasterio.plot import show
import numpy as np

# %%
lcm2019 = rio.open('data/ukregion-london.tif')
lcm2019.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'uint8',
#  'nodata': 255.0,
#  'width': 2920,
#  'height': 2254,
#  'count': 2,
#  'crs': CRS.from_epsg(27700),
#  'transform': Affine(20.0, 0.0, 503560.0,
#         0.0, -20.0, 200940.0)}

# %%
(lcm2019.bounds[2] - lcm2019.bounds[0]) / lcm2019.width
# Out:
# 20.0

# %%
lcm2019_np1 = lcm2019.read(1)
lcm2019_np2 = lcm2019.read(2)

# %%
lcm2019_np1.shape, lcm2019_np2.shape
# Out:
# ((2254, 2920), (2254, 2920))

# %%
show(lcm2019_np1, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
lcm2019_np1[0,2]
# Out:
# 255

# %%
show(lcm2019_np2)
# Out:
# <AxesSubplot:>
